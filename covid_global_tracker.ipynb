# %%
#INTRODUCTION

# %% [markdown]
# # COVID-19 Global Data Tracker
# This notebook analyzes global COVID-19 trends using data from Our World In Data. We explore cases, deaths, and vaccination trends over time and across regions.

# %%
#2. DATA LOADING
import pandas as pd

# Load data
df = pd.read_csv('owid-covid-data.csv')

# Preview
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
#3.DATA CLEANING
# Convert date to datetime
df['date'] = pd.to_datetime(df['date'])

# Filter countries
countries = ['Kenya', 'USA', 'India']
df_countries = df[df['location'].isin(countries)]

# Handle missing values
df_countries = df_countries.fillna(0)

# %%
#4.Exploratory Data Analysis (EDA)
import matplotlib.pyplot as plt
import seaborn as sns

# Plot total cases over time
plt.figure(figsize=(10, 6))
for country in countries:
    data = df_countries[df_countries['location'] == country]
    plt.plot(data['date'], data['total_cases'], label=country)

plt.title('Total COVID-19 Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.legend()
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_15416\2442901492.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=latest_data, x='location', y='total_cases', palette='Blues_d')

# %%
#5.Vaccination Progress
plt.figure(figsize=(10, 6))
for country in countries:
    data = df_countries[df_countries['location'] == country]
    plt.plot(data['date'], data['total_vaccinations'], label=country)

plt.title('Total Vaccinations Over Time')
plt.xlabel('Date')
plt.ylabel('Total Vaccinations')
plt.legend()
plt.show()

# %%
# !which python
# Out:
# 'which' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Key Insights
#
# - India had the highest number of cases over time among the selected countries.
# - Kenya's vaccination rollout started later compared to the USA and India.
# - USA showed a clear pattern of vaccination surges during specific periods.
